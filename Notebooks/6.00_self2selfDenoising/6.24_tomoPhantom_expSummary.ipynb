# %%
from cryoS2Sdrop.analyze import *
from tqdm import tqdm

PARENT_PATH = setup.PARENT_PATH

pd.options.display.float_format = "{:,.6f}".format
pd.set_option('display.max_columns', 50)

# %matplotlib inline
# %config Completer.use_jedi = False
# %load_ext autoreload
# %autoreload 2

# %%
tomo_list = [
    'tomoPhantom_model8_noisyGaussPoissVL',
    'tomoPhantom_model8_noisyGaussPoissL',
    'tomoPhantom_model8_noisyGaussPoissM',
    'tomoPhantom_model8_noisyGaussPoissH'
]
exp_list = [
    "realBernoulli_dropoutLevel_comparison",
    "realBernoulli_volMask_comparison",
    "fourierBernoulli_dropoutLevel_comparison",
    "fourierHighFreqMask_comparison",
    "fourierBernoulliVolMask_dropoutLevel_comparison"
]

data_log = []

for exp_name in exp_list:
    print(exp_name)
    for tomo in tqdm(tomo_list):

        logdir = 'data/S2SDenoising/model_logs/%s/%s/' %(tomo, exp_name)
        logdir = os.path.join(PARENT_PATH, logdir)

        _data_log = logdir_to_dataframe(logdir, clip_values=True)
        data_log.append(_data_log)

data_log = pd.concat(data_log)
data_log = data_log.reset_index().drop('index', 1)
data_log.head()
# Out:
# realBernoulli_dropoutLevel_comparison
# 100%|████████████████████████████████████████████████████████████| 4/4 [00:36<00:00,  9.22s/it]
# realBernoulli_volMask_comparison
# 100%|████████████████████████████████████████████████████████████| 4/4 [00:18<00:00,  4.62s/it]
# fourierBernoulli_dropoutLevel_comparison
# 100%|████████████████████████████████████████████████████████████| 4/4 [00:39<00:00,  9.76s/it]
# fourierHighFreqMask_comparison
# 100%|████████████████████████████████████████████████████████████| 4/4 [00:56<00:00, 14.22s/it]
# fourierBernoulliVolMask_dropoutLevel_comparison
# 100%|████████████████████████████████████████████████████████████| 4/4 [00:37<00:00,  9.39s/it]
#                                    model    version             dataset  \
# 0  realBernoulli_dropoutLevel_comparison  version_0  singleCET_dataset
# 1  realBernoulli_dropoutLevel_comparison  version_1  singleCET_dataset
# 2  realBernoulli_dropoutLevel_comparison  version_2  singleCET_dataset
# 3  realBernoulli_dropoutLevel_comparison  version_3  singleCET_dataset
# 4  realBernoulli_dropoutLevel_comparison  version_0  singleCET_dataset
#
#   TV_alpha Version_comment     transform  full_tomo_psnr  full_tomo_ssim  \
# 0        0       Bernoulli  {'p': '0.5'}       18.574526        0.184181
# 1        0       Bernoulli  {'p': '0.5'}       18.766394        0.190007
# 2        0       Bernoulli  {'p': '0.5'}       20.657969        0.201050
# 3        0       Bernoulli  {'p': '0.5'}       20.389439        0.189141
# 4        0       Bernoulli  {'p': '0.5'}       19.466251        0.177623
#
#    baseline_psnr  baseline_ssim  \
# 0       7.551045       0.035820
# 1       7.551045       0.035820
# 2       7.551045       0.035820
# 3       7.551045       0.035820
# 4       6.709743       0.025137
#
#                                            tomo_path  \
# 0  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...
# 1  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...
# 2  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...
# 3  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...
# 4  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...
#
#                                         gt_tomo_path use_deconv_as_target  \
# 0  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...                 null
# 1  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...                 null
# 2  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...                 null
# 3  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...                 null
# 4  /home/ubuntu/Thesis/data/S2SDenoising/dummy_to...                 null
#
#   predict_simRecon use_deconv_data    p  n2v_psnr  n2v_ssim  \
# 0             null           false  0.1 17.397554  0.118766
# 1             null           false  0.3 17.397554  0.118766
# 2             null           false  0.5 17.397554  0.118766
# 3             null           false  0.7 17.397554  0.118766
# 4             null           false  0.1 14.856593  0.083857
#
#    baseline_psnr_best  baseline_ssim_best  ssim_vs_baseline  \
# 0            7.551045            0.035820        414.184947
# 1            7.551045            0.035820        430.447495
# 2            7.551045            0.035820        461.277264
# 3            7.551045            0.035820        428.030531
# 4            6.709743            0.025137        606.609374
#
#    n2v_ssim_vs_baseline  psnr_vs_baseline  n2v_psnr_vs_baseline  \
# 0            231.561836        145.986165            130.399296
# 1            231.561836        148.527109            130.399296
# 2            231.561836        173.577613            130.399296
# 3            231.561836        170.021418            130.399296
# 4            233.595494        190.119200            121.418229
#
#             noise_level tomo_name  \
# 0  Gauss(0.2) + Poisson     blobs
# 1  Gauss(0.2) + Poisson     blobs
# 2  Gauss(0.2) + Poisson     blobs
# 3  Gauss(0.2) + Poisson     blobs
# 4  Gauss(0.5) + Poisson     blobs
#
#                                            pred_path
# 0  /home/ubuntu/Thesis/data/S2SDenoising/model_lo...
# 1  /home/ubuntu/Thesis/data/S2SDenoising/model_lo...
# 2  /home/ubuntu/Thesis/data/S2SDenoising/model_lo...
# 3  /home/ubuntu/Thesis/data/S2SDenoising/model_lo...
# 4  /home/ubuntu/Thesis/data/S2SDenoising/model_lo...

# %%
df = data_log.groupby(['model', 'noise_level', 'p', 'Version_comment'])['full_tomo_ssim', 'full_tomo_psnr'].max().reset_index()

df2 = data_log.groupby(['model', 'p', 'Version_comment', 'noise_level'])['n2v_ssim', 'n2v_psnr'].mean().reset_index()
df2['model'] = "N2V"
df2 = df2[['model', 'noise_level', 'p', 'Version_comment', 'n2v_ssim', 'n2v_psnr']]
df2.columns = ['model', 'noise_level', 'p', 'Version_comment', 'full_tomo_ssim', 'full_tomo_psnr']

df = pd.concat([df, df2]).sort_values(['noise_level', 'p', 'model', 'Version_comment'])

df.set_index(['noise_level', 'p'])
# Out:
#                                                                     model  \
# noise_level          p
# Gauss(0.2) + Poisson 0                                                N2V
#                      0                     fourierHighFreqMask_comparison
#                      0.1                                              N2V
#                      0.1                                              N2V
#                      0.1         fourierBernoulli_dropoutLevel_comparison
# ...                                                                   ...
# Gauss(5.0) + Poisson 0.7                   fourierHighFreqMask_comparison
#                      0.7                   fourierHighFreqMask_comparison
#                      0.7            realBernoulli_dropoutLevel_comparison
#                      0.8                                              N2V
#                      0.8  fourierBernoulliVolMask_dropoutLevel_comparison
#
#                                                 Version_comment  \
# noise_level          p
# Gauss(0.2) + Poisson 0    Fourier with hiFreqMask=1, no dropout
#                      0    Fourier with hiFreqMask=1, no dropout
#                      0.1                              Bernoulli
#                      0.1                              Bernoulli
#                      0.1                              Bernoulli
# ...                                                         ...
# Gauss(5.0) + Poisson 0.7            Fourier with hiFreqMask=0.7
#                      0.7              Fourier with hiFreqMask=1
#                      0.7                              Bernoulli
#                      0.8  Fourier Bernoulli w/ volMask. p = 0.8
#                      0.8  Fourier Bernoulli w/ volMask. p = 0.8
#
#                           full_tomo_ssim  full_tomo_psnr
# noise_level          p
# Gauss(0.2) + Poisson 0          0.118766       17.397554
#                      0          0.137921       14.992409
#                      0.1        0.118766       17.397554
#                      0.1        0.118766       17.397554
#                      0.1        0.041622        7.524512
# ...                                  ...             ...
# Gauss(5.0) + Poisson 0.7        0.073727       10.033043
#                      0.7        0.069842        9.459874
#                      0.7        0.205869       19.463266
#                      0.8        0.009138        5.402924
#                      0.8        0.029562        7.747113
#
# [140 rows x 4 columns]

# %%
for n, g in df.groupby(['noise_level']):
    aux_df = g.sort_values(['full_tomo_ssim'], ascending=False).drop_duplicates(['full_tomo_ssim'])
    display(aux_df)
# Out:
#                                               model           noise_level  \
# 48            realBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 47            realBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 49            realBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 63                 realBernoulli_volMask_comparison  Gauss(0.2) + Poisson
# 46            realBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 62                 realBernoulli_volMask_comparison  Gauss(0.2) + Poisson
# 32                   fourierHighFreqMask_comparison  Gauss(0.2) + Poisson
# 35                   fourierHighFreqMask_comparison  Gauss(0.2) + Poisson
# 33                   fourierHighFreqMask_comparison  Gauss(0.2) + Poisson
# 34                   fourierHighFreqMask_comparison  Gauss(0.2) + Poisson
# 32                                              N2V  Gauss(0.2) + Poisson
# 3   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 19         fourierBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 2   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 18         fourierBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 1   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 17         fourierBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 0   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.2) + Poisson
# 16         fourierBernoulli_dropoutLevel_comparison  Gauss(0.2) + Poisson
#
#       p                        Version_comment  full_tomo_ssim  full_tomo_psnr
# 48  0.5                              Bernoulli        0.201050       20.657969
# 47  0.3                              Bernoulli        0.190007       18.766394
# 49  0.7                              Bernoulli        0.189141       20.389439
# 63  0.5       Volumetric mask(0.3) with prob=1        0.185681       20.148006
# 46  0.1                              Bernoulli        0.184181       18.574526
# 62  0.5     Volumetric mask(0.3) with prob=0.5        0.157667       18.979057
# 32    0  Fourier with hiFreqMask=1, no dropout        0.137921       14.992409
# 35  0.7              Fourier with hiFreqMask=1        0.136950       15.389587
# 33  0.7            Fourier with hiFreqMask=0.5        0.132066       17.322273
# 34  0.7            Fourier with hiFreqMask=0.7        0.131748       16.785675
# 32    0  Fourier with hiFreqMask=1, no dropout        0.118766       17.397554
# 3   0.8  Fourier Bernoulli w/ volMask. p = 0.8        0.108767       15.456599
# 19  0.7                              Bernoulli        0.101708       15.749643
# 2   0.7  Fourier Bernoulli w/ volMask. p = 0.7        0.087219       13.472615
# 18  0.5                              Bernoulli        0.084462       12.152400
# 1   0.5  Fourier Bernoulli w/ volMask. p = 0.5        0.073732       12.192923
# 17  0.3                              Bernoulli        0.057412        8.956050
# 0   0.3  Fourier Bernoulli w/ volMask. p = 0.3        0.056805        9.208850
# 16  0.1                              Bernoulli        0.041622        7.524512
#                                               model           noise_level  \
# 52            realBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 53            realBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 51            realBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 50            realBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 65                 realBernoulli_volMask_comparison  Gauss(0.5) + Poisson
# 64                 realBernoulli_volMask_comparison  Gauss(0.5) + Poisson
# 38                   fourierHighFreqMask_comparison  Gauss(0.5) + Poisson
# 39                   fourierHighFreqMask_comparison  Gauss(0.5) + Poisson
# 37                   fourierHighFreqMask_comparison  Gauss(0.5) + Poisson
# 36                   fourierHighFreqMask_comparison  Gauss(0.5) + Poisson
# 23         fourierBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 59                                              N2V  Gauss(0.5) + Poisson
# 7   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 6   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 22         fourierBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 5   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 21         fourierBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 4   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(0.5) + Poisson
# 20         fourierBernoulli_dropoutLevel_comparison  Gauss(0.5) + Poisson
#
#       p                        Version_comment  full_tomo_ssim  full_tomo_psnr
# 52  0.5                              Bernoulli        0.184604       19.927916
# 53  0.7                              Bernoulli        0.183272       20.302324
# 51  0.3                              Bernoulli        0.178560       18.733425
# 50  0.1                              Bernoulli        0.177623       19.466251
# 65  0.5       Volumetric mask(0.3) with prob=1        0.175407       19.739700
# 64  0.5     Volumetric mask(0.3) with prob=0.5        0.156496       19.015287
# 38  0.7            Fourier with hiFreqMask=0.7        0.117544       15.276067
# 39  0.7              Fourier with hiFreqMask=1        0.116466       14.305648
# 37  0.7            Fourier with hiFreqMask=0.5        0.115628       15.943051
# 36    0  Fourier with hiFreqMask=1, no dropout        0.112899       13.213551
# 23  0.7                              Bernoulli        0.085040       14.076249
# 59  0.7                              Bernoulli        0.083857       14.856593
# 7   0.8  Fourier Bernoulli w/ volMask. p = 0.8        0.080110       14.049727
# 6   0.7  Fourier Bernoulli w/ volMask. p = 0.7        0.062717       11.395013
# 22  0.5                              Bernoulli        0.053992        9.810166
# 5   0.5  Fourier Bernoulli w/ volMask. p = 0.5        0.047999        9.347664
# 21  0.3                              Bernoulli        0.036997        7.626933
# 4   0.3  Fourier Bernoulli w/ volMask. p = 0.3        0.034996        7.212217
# 20  0.1                              Bernoulli        0.028505        6.895105
#                                               model           noise_level  \
# 56            realBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 57            realBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 67                 realBernoulli_volMask_comparison  Gauss(1.0) + Poisson
# 54            realBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 66                 realBernoulli_volMask_comparison  Gauss(1.0) + Poisson
# 55            realBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 42                   fourierHighFreqMask_comparison  Gauss(1.0) + Poisson
# 41                   fourierHighFreqMask_comparison  Gauss(1.0) + Poisson
# 40                   fourierHighFreqMask_comparison  Gauss(1.0) + Poisson
# 11  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 27         fourierBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 10  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 26         fourierBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 9   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 25         fourierBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 8   fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(1.0) + Poisson
# 26                                              N2V  Gauss(1.0) + Poisson
# 24         fourierBernoulli_dropoutLevel_comparison  Gauss(1.0) + Poisson
#
#       p                        Version_comment  full_tomo_ssim  full_tomo_psnr
# 56  0.5                              Bernoulli        0.189974       20.097416
# 57  0.7                              Bernoulli        0.185155       20.084391
# 67  0.5       Volumetric mask(0.3) with prob=1        0.162583       19.544762
# 54  0.1                              Bernoulli        0.161980       18.031456
# 66  0.5     Volumetric mask(0.3) with prob=0.5        0.158597       19.175488
# 55  0.3                              Bernoulli        0.154236       19.357868
# 42  0.7              Fourier with hiFreqMask=1        0.104736       13.085690
# 41  0.7            Fourier with hiFreqMask=0.7        0.102130       13.785501
# 40  0.7            Fourier with hiFreqMask=0.5        0.101731       13.692024
# 11  0.8  Fourier Bernoulli w/ volMask. p = 0.8        0.069007       10.144032
# 27  0.7                              Bernoulli        0.058289       11.180467
# 10  0.7  Fourier Bernoulli w/ volMask. p = 0.7        0.042595        9.300976
# 26  0.5                              Bernoulli        0.038007        8.313864
# 9   0.5  Fourier Bernoulli w/ volMask. p = 0.5        0.033283        7.621122
# 25  0.3                              Bernoulli        0.027360        7.035980
# 8   0.3  Fourier Bernoulli w/ volMask. p = 0.3        0.026582        6.986612
# 26  0.5                              Bernoulli        0.026238        8.315987
# 24  0.1                              Bernoulli        0.021670        6.548263
#                                               model           noise_level  \
# 61            realBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 69                 realBernoulli_volMask_comparison  Gauss(5.0) + Poisson
# 60            realBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 59            realBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 58            realBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 68                 realBernoulli_volMask_comparison  Gauss(5.0) + Poisson
# 43                   fourierHighFreqMask_comparison  Gauss(5.0) + Poisson
# 44                   fourierHighFreqMask_comparison  Gauss(5.0) + Poisson
# 45                   fourierHighFreqMask_comparison  Gauss(5.0) + Poisson
# 15  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 31         fourierBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 14  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 30         fourierBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 13  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 12  fourierBernoulliVolMask_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 29         fourierBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 28         fourierBernoulli_dropoutLevel_comparison  Gauss(5.0) + Poisson
# 27                                              N2V  Gauss(5.0) + Poisson
#
#       p                        Version_comment  full_tomo_ssim  full_tomo_psnr
# 61  0.7                              Bernoulli        0.205869       19.463266
# 69  0.5       Volumetric mask(0.3) with prob=1        0.186640       17.910009
# 60  0.5                              Bernoulli        0.180237       18.835115
# 59  0.3                              Bernoulli        0.160395       18.876844
# 58  0.1                              Bernoulli        0.152175       17.807299
# 68  0.5     Volumetric mask(0.3) with prob=0.5        0.135292       18.084280
# 43  0.7            Fourier with hiFreqMask=0.5        0.080057       10.967812
# 44  0.7            Fourier with hiFreqMask=0.7        0.073727       10.033043
# 45  0.7              Fourier with hiFreqMask=1        0.069842        9.459874
# 15  0.8  Fourier Bernoulli w/ volMask. p = 0.8        0.029562        7.747113
# 31  0.7                              Bernoulli        0.027781        8.097518
# 14  0.7  Fourier Bernoulli w/ volMask. p = 0.7        0.024369        7.323938
# 30  0.5                              Bernoulli        0.019648        7.077842
# 13  0.5  Fourier Bernoulli w/ volMask. p = 0.5        0.018266        6.690954
# 12  0.3  Fourier Bernoulli w/ volMask. p = 0.3        0.014716        6.453211
# 29  0.3                              Bernoulli        0.014434        6.548420
# 28  0.1                              Bernoulli        0.012382        6.178358
# 27  0.5                              Bernoulli        0.009138        5.402924
